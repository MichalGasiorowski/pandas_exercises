# %% [markdown]
# # Visualizing the Titanic Disaster

# %% [markdown]
# ### Introduction:
#
# This exercise is based on the titanic Disaster dataset avaiable at [Kaggle](https://www.kaggle.com/c/titanic).
# To know more about the variables check [here](https://www.kaggle.com/c/titanic/data)
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Titanic_Desaster/train.csv)

# %% [markdown]
# ### Step 3. Assign it to a variable titanic

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Titanic_Desaster/train.csv")

# %% [markdown]
# ### Step 4. Set PassengerId as the index

# %%
titanic = titanic.set_index("PassengerId")
titanic.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# ### Step 5. Create a pie chart presenting the male/female proportion

# %%
#titanic.plot?
titanic.Sex.value_counts().plot(kind='pie', autopct='%1.2f%%', shadow=True, fontsize=14)

#df.plot(kind='pie', y = 'total_arrests', ax=ax1, autopct='%1.1f%%', 
# startangle=90, shadow=False, labels=df['officer_name'], legend = False, fontsize=14)

# %% [markdown]
# ### Step 6. Create a scatterplot with the Fare payed and the Age, differ the plot color by gender

# %%
#sns.scatterplot(data=titanic, x="Age", y="Fare", hue="Sex")

lm = sns.lmplot(data=titanic, x="Age", y="Fare", hue="Sex", fit_reg=False, palette=)

lm.set(title="Age vs Fare")

# %% [markdown]
# ### Step 7. How many people survived?

# %%
titanic["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# ### Step 8. Create a histogram with the Fare payed

# %%
#sns.distplot?
sns.distplot(titanic["Fare"])

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
sns.catplot(x="Sex", y="Survived", hue="Pclass", kind="bar", data=titanic)

# %%
#sns.catplot(x="Fare", y="Survived", hue="Pclass", kind="bar", data=titanic)
sns.catplot(x="Sex", y="Fare", hue="Survived", kind="bar", data=titanic)

# %%
sns.pairplot(data=titanic, hue="Sex")
